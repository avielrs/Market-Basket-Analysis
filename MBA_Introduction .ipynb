# %% [markdown]
# # An Introduction to Market Basket Analysis
# Data taken from [Kaggle](https://www.kaggle.com/shazadudwadia/supermarket). I picked this dataset because I wanted to gain experience applying Market Basket Analysis with a small dataset. Market Basket Analysis is a data mining technique and rule-based algorithm that can learn through relationships and can be utilized within ecommerce and marketing strategies. Through this analysis we can determine how to place items in a store such that item A and item B are near each other, or if a customer purchases one item we might consider targeting them with advertisements with another item, we can as well consider group discounts, and providing a recommender system based on frequent co-purchasing.
#
# #### Project Goal: Create a recommendor system based off of co-frequent purchasing. For example when item A was purchased, then item B was purchased as well in the same transaction.
#
# Links for Reference: \
# https://towardsdatascience.com/mba-for-breakfast-4c18164ef82b \
# https://www.youtube.com/watch?v=WGlMlS_Yydk&t=8s

# %%
# Import packages
import pandas as pd
import numpy as np
import matplotlib as pl

# %%
# Import as dataframe
df = pd.read_csv('MarketBasketAnalysis/GroceryStoreDataSet.csv', header=None)

# %%
# View first 5 rows of dataframe
df.head()
# Out:
#                                0
# 0             MILK,BREAD,BISCUIT
# 1  BREAD,MILK,BISCUIT,CORNFLAKES
# 2            BREAD,TEA,BOURNVITA
# 3           JAM,MAGGI,BREAD,MILK
# 4              MAGGI,TEA,BISCUIT

# %% [markdown]
# In order to run the market basket analysis, we must first start with a list of transactions:
#
#     Transaction 1: 'MILK', 'BREAD', 'BISCUIT'
#     Transaction 2: 'BREAD', 'MILK', 'BISCUIT', 'CORNFLAKES'
#     Transaction 3: 'BREAD', 'TEA', 'BOURNVITA'
#     Transaction 4: 'JAM', 'MAGGI', 'BREAD', 'MILK'
#
# BASKET =
# [['MILK', 'BREAD', 'BISCUIT'], \
#  ['BREAD', 'MILK', 'BISCUIT', 'CORNFLAKES'], \
#  ['BREAD', 'TEA', 'BOURNVITA'], \
#  ['JAM', 'MAGGI', 'BREAD', 'MILK']]
#
# Next we must transform this list into a dummy DataFrame where the

# %%
# Make dataframe into a list, where each list of items is a transaction:
# Transaction 1: Milk, Bread, Biscuit
# Transaction 2: Bread, Milk, Biscuit, Cornflakes
# Transaction 3: Bread, Tea, Bournvita

basket = []

df.values[0, 0].split(',')

for i in range(len(df)):
    basket.append(df.values[i, 0].split(','))

# %%
# View basket
basket
# Out:
# [['MILK', 'BREAD', 'BISCUIT'],
#  ['BREAD', 'MILK', 'BISCUIT', 'CORNFLAKES'],
#  ['BREAD', 'TEA', 'BOURNVITA'],
#  ['JAM', 'MAGGI', 'BREAD', 'MILK'],
#  ['MAGGI', 'TEA', 'BISCUIT'],
#  ['BREAD', 'TEA', 'BOURNVITA'],
#  ['MAGGI', 'TEA', 'CORNFLAKES'],
#  ['MAGGI', 'BREAD', 'TEA', 'BISCUIT'],
#  ['JAM', 'MAGGI', 'BREAD', 'TEA'],
#  ['BREAD', 'MILK'],
#  ['COFFEE', 'COCK', 'BISCUIT', 'CORNFLAKES'],
#  ['COFFEE', 'COCK', 'BISCUIT', 'CORNFLAKES'],
#  ['COFFEE', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'COCK'],
#  ['BREAD', 'SUGER', 'BISCUIT'],
#  ['COFFEE', 'SUGER', 'CORNFLAKES'],
#  ['BREAD', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'SUGER'],
#  ['BREAD', 'COFFEE', 'SUGER'],
#  ['TEA', 'MILK', 'COFFEE', 'CORNFLAKES']]

# %%
# Import mlxtend packages

from mlxtend.preprocessing import TransactionEncoder
import itertools  

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
# Instantiate
te = TransactionEncoder()

# Fit and Transform
item = te.fit(basket).transform(basket)

# Create new DataFrame
df = pd.DataFrame(item, columns=te.columns_)
df.head()
# Out:
#    BISCUIT  BOURNVITA  BREAD   COCK  COFFEE  CORNFLAKES    JAM  MAGGI   MILK  \
# 0     True      False   True  False   False       False  False  False   True
# 1     True      False   True  False   False        True  False  False   True
# 2    False       True   True  False   False       False  False  False  False
# 3    False      False   True  False   False       False   True   True   True
# 4     True      False  False  False   False       False  False   True  False
#
#    SUGER    TEA
# 0  False  False
# 1  False  False
# 2  False   True
# 3  False  False
# 4  False   True

# %%
frequent_itemsets = apriori(df, min_support = 0.005, use_colnames=True)

# %%
frequent_itemsets
# Out:
#     support                             itemsets
# 0      0.35                            (BISCUIT)
# 1      0.20                          (BOURNVITA)
# 2      0.65                              (BREAD)
# 3      0.15                               (COCK)
# 4      0.40                             (COFFEE)
# ..      ...                                  ...
# 78     0.05         (BREAD, BISCUIT, TEA, MAGGI)
# 79     0.10  (COCK, CORNFLAKES, BISCUIT, COFFEE)
# 80     0.05            (BREAD, MILK, JAM, MAGGI)
# 81     0.05             (BREAD, JAM, TEA, MAGGI)
# 82     0.05      (COFFEE, MILK, CORNFLAKES, TEA)
#
# [83 rows x 2 columns]

# %%
# add 
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

frequent_itemsets
# Out:
#     support                             itemsets  length
# 0      0.35                            (BISCUIT)       1
# 1      0.20                          (BOURNVITA)       1
# 2      0.65                              (BREAD)       1
# 3      0.15                               (COCK)       1
# 4      0.40                             (COFFEE)       1
# ..      ...                                  ...     ...
# 78     0.05         (BREAD, BISCUIT, TEA, MAGGI)       4
# 79     0.10  (COCK, CORNFLAKES, BISCUIT, COFFEE)       4
# 80     0.05            (BREAD, MILK, JAM, MAGGI)       4
# 81     0.05             (BREAD, JAM, TEA, MAGGI)       4
# 82     0.05      (COFFEE, MILK, CORNFLAKES, TEA)       4
#
# [83 rows x 3 columns]

# %%
# getting th item sets with length = 2 and support more than 5%

items = frequent_itemsets[ (frequent_itemsets['length'] == 2) &
                   (frequent_itemsets['support'] >= 0.05) ]

# %%
items
# Out:
#     support               itemsets  length
# 11     0.20       (BREAD, BISCUIT)       2
# 12     0.10        (COCK, BISCUIT)       2
# 13     0.10      (BISCUIT, COFFEE)       2
# 14     0.15  (CORNFLAKES, BISCUIT)       2
# 15     0.10       (BISCUIT, MAGGI)       2
# 16     0.10        (MILK, BISCUIT)       2
# 17     0.05       (SUGER, BISCUIT)       2
# 18     0.10         (BISCUIT, TEA)       2
# 19     0.15     (BREAD, BOURNVITA)       2
# 20     0.05    (BOURNVITA, COFFEE)       2
# 21     0.10     (SUGER, BOURNVITA)       2
# 22     0.10       (BOURNVITA, TEA)       2
# 23     0.05          (BREAD, COCK)       2
# 24     0.15        (BREAD, COFFEE)       2
# 25     0.05    (BREAD, CORNFLAKES)       2
# 26     0.10           (BREAD, JAM)       2
# 27     0.15         (BREAD, MAGGI)       2
# 28     0.20          (BREAD, MILK)       2
# 29     0.20         (BREAD, SUGER)       2
# 30     0.20           (BREAD, TEA)       2
# 31     0.15         (COCK, COFFEE)       2
# 32     0.10     (COCK, CORNFLAKES)       2
# 33     0.20   (CORNFLAKES, COFFEE)       2
# 34     0.05         (MILK, COFFEE)       2
# 35     0.20        (SUGER, COFFEE)       2
# 36     0.05          (COFFEE, TEA)       2
# 37     0.05    (CORNFLAKES, MAGGI)       2
# 38     0.10     (MILK, CORNFLAKES)       2
# 39     0.05    (SUGER, CORNFLAKES)       2
# 40     0.10      (CORNFLAKES, TEA)       2
# 41     0.10           (JAM, MAGGI)       2
# 42     0.05            (MILK, JAM)       2
# 43     0.05             (JAM, TEA)       2
# 44     0.05          (MILK, MAGGI)       2
# 45     0.20           (TEA, MAGGI)       2
# 46     0.05            (MILK, TEA)       2

# %%
basket = [list(x) for x in items['itemsets']]

# %%
basket
# Out:
# [['BREAD', 'BISCUIT'],
#  ['COCK', 'BISCUIT'],
#  ['BISCUIT', 'COFFEE'],
#  ['CORNFLAKES', 'BISCUIT'],
#  ['BISCUIT', 'MAGGI'],
#  ['MILK', 'BISCUIT'],
#  ['SUGER', 'BISCUIT'],
#  ['BISCUIT', 'TEA'],
#  ['BREAD', 'BOURNVITA'],
#  ['BOURNVITA', 'COFFEE'],
#  ['SUGER', 'BOURNVITA'],
#  ['BOURNVITA', 'TEA'],
#  ['BREAD', 'COCK'],
#  ['BREAD', 'COFFEE'],
#  ['BREAD', 'CORNFLAKES'],
#  ['BREAD', 'JAM'],
#  ['BREAD', 'MAGGI'],
#  ['BREAD', 'MILK'],
#  ['BREAD', 'SUGER'],
#  ['BREAD', 'TEA'],
#  ['COCK', 'COFFEE'],
#  ['COCK', 'CORNFLAKES'],
#  ['CORNFLAKES', 'COFFEE'],
#  ['MILK', 'COFFEE'],
#  ['SUGER', 'COFFEE'],
#  ['COFFEE', 'TEA'],
#  ['CORNFLAKES', 'MAGGI'],
#  ['MILK', 'CORNFLAKES'],
#  ['SUGER', 'CORNFLAKES'],
#  ['CORNFLAKES', 'TEA'],
#  ['JAM', 'MAGGI'],
#  ['MILK', 'JAM'],
#  ['JAM', 'TEA'],
#  ['MILK', 'MAGGI'],
#  ['TEA', 'MAGGI'],
#  ['MILK', 'TEA']]

# %%
# Instantiate
te = TransactionEncoder()

# Fit and Transform
item = te.fit(basket).transform(basket)

# Create new DataFrame
df = pd.DataFrame(item, columns=te.columns_)
df.head()
# Out:
#    BISCUIT  BOURNVITA  BREAD   COCK  COFFEE  CORNFLAKES    JAM  MAGGI   MILK  \
# 0     True      False   True  False   False       False  False  False  False
# 1     True      False  False   True   False       False  False  False  False
# 2     True      False  False  False    True       False  False  False  False
# 3     True      False  False  False   False        True  False  False  False
# 4     True      False  False  False   False       False  False   True  False
#
#    SUGER    TEA
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False
# 4  False  False

# %%
x = apriori(df, min_support=0.005, use_colnames=True)

# %%
#take a look at the help for ways we can use this function
association_rules = association_rules(x, metric="lift", min_threshold=1)

# %%
association_rules
# Out:
#      antecedents   consequents  antecedent support  consequent support  \
# 0         (COCK)     (BISCUIT)            0.111111            0.222222
# 1      (BISCUIT)        (COCK)            0.222222            0.111111
# 2    (BOURNVITA)      (COFFEE)            0.111111            0.222222
# 3       (COFFEE)   (BOURNVITA)            0.222222            0.111111
# 4        (SUGER)   (BOURNVITA)            0.138889            0.111111
# 5    (BOURNVITA)       (SUGER)            0.111111            0.138889
# 6    (BOURNVITA)         (TEA)            0.111111            0.222222
# 7          (TEA)   (BOURNVITA)            0.222222            0.111111
# 8         (COCK)      (COFFEE)            0.111111            0.222222
# 9       (COFFEE)        (COCK)            0.222222            0.111111
# 10        (COCK)  (CORNFLAKES)            0.111111            0.222222
# 11  (CORNFLAKES)        (COCK)            0.222222            0.111111
# 12         (JAM)       (MAGGI)            0.111111            0.166667
# 13       (MAGGI)         (JAM)            0.166667            0.111111
# 14        (MILK)         (JAM)            0.194444            0.111111
# 15         (JAM)        (MILK)            0.111111            0.194444
# 16         (JAM)         (TEA)            0.111111            0.222222
# 17         (TEA)         (JAM)            0.222222            0.111111
#
#      support  confidence      lift  leverage  conviction
# 0   0.027778    0.250000  1.125000  0.003086    1.037037
# 1   0.027778    0.125000  1.125000  0.003086    1.015873
# 2   0.027778    0.250000  1.125000  0.003086    1.037037
# 3   0.027778    0.125000  1.125000  0.003086    1.015873
# 4   0.027778    0.200000  1.800000  0.012346    1.111111
# 5   0.027778    0.250000  1.800000  0.012346    1.148148
# 6   0.027778    0.250000  1.125000  0.003086    1.037037
# 7   0.027778    0.125000  1.125000  0.003086    1.015873
# 8   0.027778    0.250000  1.125000  0.003086    1.037037
# 9   0.027778    0.125000  1.125000  0.003086    1.015873
# 10  0.027778    0.250000  1.125000  0.003086    1.037037
# 11  0.027778    0.125000  1.125000  0.003086    1.015873
# 12  0.027778    0.250000  1.500000  0.009259    1.111111
# 13  0.027778    0.166667  1.500000  0.009259    1.066667
# 14  0.027778    0.142857  1.285714  0.006173    1.037037
# 15  0.027778    0.250000  1.285714  0.006173    1.074074
# 16  0.027778    0.250000  1.125000  0.003086    1.037037
# 17  0.027778    0.125000  1.125000  0.003086    1.015873

# %%
top_rated = association_rules[association_rules['antecedents'] == frozenset({'COFFEE'})].sort_values(by=['lift'], ascending=False)

# %%
top_rated
# Out:
#   antecedents  consequents  antecedent support  consequent support   support  \
# 3    (COFFEE)  (BOURNVITA)            0.222222            0.111111  0.027778
# 9    (COFFEE)       (COCK)            0.222222            0.111111  0.027778
#
#    confidence   lift  leverage  conviction
# 3       0.125  1.125  0.003086    1.015873
# 9       0.125  1.125  0.003086    1.015873

# %%
def recommendation(item):
    
    """
    A function that takes in a item and returns the top 2 items are recommended to purchase with this product
    
    Input: Item (string)
    Output: Top 2 recommended products
    
    """
    
    # where antecedents = item i.e. COFFEE, sort table by lift in ascending order
    top_rated = association_rules[association_rules['antecedents'] == frozenset({item})].sort_values(by=['lift'], ascending=False)
    
    # Create empty list for Products
    product = []

    # Create a table that lists the consequents from top_rated
    for i in np.arange(0, len(top_rated), 1):
        
        # Append product ID for consquents results 
        product.append(list(top_rated['consequents'].iloc[i]))

    #Create a dataframe with consequents Product
    product = pd.DataFrame(product, columns=['product recommendation'])
    
    # Return the top 2 from consequents product from the list
    
    return product.head(2)

# %%
recommendation('COFFEE')
# Out:
#   product recommendation
# 0              BOURNVITA
# 1                   COCK
